# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d.csv")
df
# Out:
#                     Name                     10k para (publicly accessible)  \
# 0   Bristol-Myers Squibb  The effective tax rate is lower than the U.S. ...
# 1                 Pfizer  As of December 31, 2014, we have not made a U....
# 2              Eli Lilly  At December 31, 2013 , U.S. income taxes have ...
# 3                  Merck  At December 31, 2014, foreign earnings of $60....
# 4                Abbott   Undistributed earnings reinvested indefinitely...
# 5               Novartis  At December 31, 2014, unremitted earnings of U...
# 6                 Abbvie  Deferred income taxes have not been provided o...
# 7                  Amgen  At December 31, 2014, the cumulative amount of...
# 8                    J&J  At December 28, 2014, the cumulative amounts o...
# 9                 Total:                                                NaN
# 10                   NaN                                                NaN
# 11                   NaN                                                NaN
# 12                   NaN                                                NaN
# 13                   NaN                                                NaN
# 14                   NaN                                                NaN
# 15                   NaN                                                NaN
# 16                   NaN                                                NaN
# 17                   NaN                                                NaN
# 18                   NaN                                                NaN
# 19                   NaN                                                NaN
# 20                   NaN                                                NaN
# 21                   NaN                                                NaN
# 22                   NaN                                                NaN
#
#     Undistributed Offshore            Taxes Owed  Intangibles listed  \
# 0             2.400000e+10            8400000000        1.700000e+09
# 1             7.400000e+10           25900000000        3.500000e+10
# 2             2.374000e+10            8200000000        2.800000e+09
# 3             6.000000e+10           21000000000        2.030000e+10
# 4             2.300000e+10            8050000000        6.100000e+09
# 5             5.500000e+10           19200000000        2.380000e+10
# 6             2.300000e+10            8050000000        1.500000e+09
# 7             2.930000e+10           10500000000        1.260000e+10
# 8             5.340000e+10           18600000000        2.720000e+10
# 9             3.654400e+11          127900000000        1.310000e+11
# 10                     NaN                   NaN                 NaN
# 11                     NaN                   NaN                 NaN
# 12                     NaN                   NaN                 NaN
# 13                     NaN                   NaN                 NaN
# 14                     NaN  Bristol-Myers Squibb        1.050000e+11
# 15                     NaN                Pfizer        1.913000e+11
# 16                     NaN             Eli Lilly        8.510000e+10
# 17                     NaN                 Merck        1.445000e+11
# 18                     NaN                Abbott        6.140000e+10
# 19                     NaN              Novartis        1.970000e+11
# 20                     NaN                Abbvie        8.360000e+10
# 21                     NaN                 Amgen        1.097000e+11
# 22                     NaN                   J&J        2.680000e+11
#
#        Market Cap                                  Market Cap Source  \
# 0    105000000000                   http://finance.yahoo.com/q?s=BMY
# 1    191300000000                   http://finance.yahoo.com/q?s=PFE
# 2     85100000000  http://finance.yahoo.com/q?s=LLY&fr=uh3_financ...
# 3    144500000000                   http://finance.yahoo.com/q?s=MRK
# 4     61400000000                   http://finance.yahoo.com/q?s=ABT
# 5    197000000000  https://finance.yahoo.com/q/ks?s=NVS+Key+Stati...
# 6     83600000000                  http://finance.yahoo.com/q?s=ABBV
# 7    109700000000                  http://finance.yahoo.com/q?s=AMGN
# 8    268000000000                   http://finance.yahoo.com/q?s=JNJ
# 9   1140600000000                                                NaN
# 10            NaN                                                NaN
# 11            NaN                                                NaN
# 12            NaN                                                NaN
# 13            NaN                                                NaN
# 14            NaN                                                NaN
# 15         =D2/C2                                             =D2/C2
# 16            NaN                                                NaN
# 17            NaN                                                NaN
# 18            NaN                                                NaN
# 19            NaN                                             =D2/C2
# 20            NaN                                                NaN
# 21            NaN                                                NaN
# 22            NaN                                                NaN
#
#            NTA                            NTA & Intangibles source
# 0    6000000000  https://finance.yahoo.com/q/bs?s=BMY+Balance+S...
# 1      -5934000  https://finance.yahoo.com/q/bs?s=PFE+Balance+S...
# 2   10700000000  https://finance.yahoo.com/q/bs?s=LLY+Balance+S...
# 3   15200000000  https://finance.yahoo.com/q/bs?s=MRK+Balance+S...
# 4    5200000000  https://finance.yahoo.com/q/bs?s=ABT+Balance+S...
# 5   17600000000  https://finance.yahoo.com/q/bs?s=NVS+Balance+S...
# 6      -5633000  https://finance.yahoo.com/q/bs?s=ABBV+Balance+...
# 7      -1703000  https://finance.yahoo.com/q/bs?s=AMGN+Balance+...
# 8   20600000000  https://finance.yahoo.com/q/bs?s=JNJ+Balance+S...
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# 13          NaN                                                NaN
# 14          NaN                                                NaN
# 15          NaN                                                NaN
# 16          NaN                                                NaN
# 17          NaN                                                NaN
# 18          NaN                                                NaN
# 19          NaN                                                NaN
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 22          NaN                                                NaN

# %%
# %pylab inline
from pylab import *

for idx in range(9):
    taxes_owed = float(df.iloc[[idx]]["Taxes Owed"][idx].replace(",", ""))
    market_cap = float(df.iloc[[idx]]["Market Cap"][idx])
    name = df.iloc[[idx]]["Name"][idx]

    figure(1, figsize=(6,6))
    ax = axes([0.1, 0.1, 0.8, 0.8])
    labels = 'Taxes Owed', ''
    fracs = [taxes_owed, market_cap - taxes_owed]
    explode=(0, 0.05)
    pie(fracs, explode=explode, labels=labels,
                autopct='%1.1f%%', shadow=False, startangle=90,
                colors=["#E4AB8E", "#B8C6D3"]
       )


    title(name)

    show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['info', 'linalg', 'draw_if_interactive', 'random', 'fft', 'power']
# `%matplotlib` prevents importing * from pylab and numpy
